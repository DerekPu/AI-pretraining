# %% [markdown]
# # Convolution, Activation and Pooling

# %% [markdown]
# ### Convolution operation

# %%
# !pip install opencv-python
# Out:
# ...
# WARNING: You are using pip version 20.3; however, version 21.1.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image = cv2.imread('images/dog-cat.jpg')
plt.imshow(image[:, :, ::-1])
plt.show()

# %%
# Creating our 3 x 3 kernel
kernel_3x3 = np.ones((5, 5), np.float32)/99
# We use the cv2.fitler2D to conovlve the kernal with an image 
blurred = cv2.filter2D(image, -1, kernel_3x3)
plt.imshow(blurred[:, :, ::-1])
plt.show()

# %%
# Creating our 7 x 7 kernel
kernel_7x7 = np.ones((7, 7), np.float32) / 20

blurred2 = cv2.filter2D(image, -1, kernel_7x7)
plt.imshow(blurred2[:, :, ::-1])
plt.show()

# %% [markdown]
# ## ReLU activation

# %%
image = np.random.randint(-5, 5, size=(9, 9))
print(image)
# Out:
# [[ 0 -2  4 -5  0 -1  3  3  3]
#  [ 2 -5  3  1 -4 -2 -2 -2 -5]
#  [-5 -2  4 -2 -4  1 -1  1 -1]
#  [-5 -1 -3  4  2  0 -1 -3 -2]
#  [ 2 -4 -5 -1  4  2 -5 -4 -1]
#  [-4 -5  2  0 -5  4  4 -1  0]
#  [-3 -3  1 -5 -4 -2  4  1  2]
#  [-5  3 -2 -4  0  2  0  1  2]
#  [-1 -1  0  3  3 -1  3 -4  2]]

# %%
# please write your solution

# %% [markdown]
# ## Pooling

# %%
# pooling kernel: 3*3
# stride: 3

# %%
# Max pooling:

# %%
# Average pooling:
